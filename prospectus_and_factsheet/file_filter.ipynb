# %%
import pandas as pd
import os

# %%
df = pd.read_csv('scraped_data_links.csv')
ignore_list = [
    'IE00043JTBZ6', 'IE000G1ER031', 'GB0000796242', 'IE00B7F9FM77', 'IE000IQEE9W5', 'IE000J9WOV28', 'IE000RC8IBP7', 'IE000YLJKBQ9', 'IE000Z0DPSS4', 
    'IE00B9NNHV84', 'IE00BGR6TZ09', 'IE00BKPHWW11', 'IE00BKPHWX28', 'IE00BLSP4015', 'IE00BLSP4122', 'IE00BMG7P694', 'IE00BMG7P819', 'IE00BMG7P926', 
    'IE00BN6Q8645', 'IE00BWDBJ409', 'LU0057025933', 'LU0081336892', 'LU0110060430', 'LU0156897901', 'LU0157308031', 'LU0232524495', 'LU2375672263', 
    'LU1979441026', 'LU1883994011', 'LU1883993989', 'LU1861127766', 'LU1509826696', 'LU1345481854', 'LU1235258685', 'LU1084809042', 'LU1069345178', 
    'LU1037948970', 'LU1035781084', 'LU0981926206', 'LU0965509440', 'LU0965509283', 'LU0965509101', 'LU0965509010', 'LU0965508988', 'LU0965506933', 
    'LU0965506859', 'LU0905234570', 'LU0905234497', 'LU0805983789', 'LU0805981734', 'LU0800111485', 'LU0787776995', 'LU0736559351', 'LU0736559278', 
    'LU0736558973', 'LU0683600729', 'LU0683595895', 'LU0683595465', 'LU0592507528', 'LU0592507361', 'LU0592505829', 'LU0592505407', 'LU0511406216', 
    'LU0511405911', 'LU0449515922', 'LU0443062806', 'LU0417103578', 'LU0417103495', 'LU0417103065', 'LU0417102927', 'LU0289962507', 'LU0289961442', 
    'LU0289960550', 'LU0289958901', 'LU0289941410', 'LU0289924671', 'LU0289923608', 'LU0289739699', 'LU0289739343', 'LU0999521056', 'LU2056362770', 
    'LU1573120497', 'LU0288029860', 'LU0288029514', 'LU1573120224', 'LU0258954444', 'LU0689626256', 'LU0689625878', 'LU0683596430', 'LU0633140727', 
    'LU1127388517', 'LU1127388434', 'LU1127387386', 'LU1563521951', 'LU0987487419', 'LU0539802446', 'LU0258954014', 'LU0772969993', 'LU0314587907', 
    'LU0539801802', 'LU0704905362', 'LU0905233846', 'LU0328307730'
    ]

# %%
new_df = df[~df['isin name'].isin(ignore_list)]
remove_df = df[df['isin name'].isin(ignore_list)]

# %%
pdf_files = r'D:\\sriram\\agrud\\prospectus_and_factsheet\\factsheet\\'
date2 = '20220426'
for i,row in remove_df.iterrows():
        isin = row[3]
        master_id = row[0]
        file_name = f'{master_id}_{date2}'
        file = pdf_files+file_name+'.pdf'
        os.remove(file)

# %%
new_df.to_csv('scraped_data_links.csv',index=False,header=['master id','isin name','factsheet link','prospectus link'])

# %%
df[df['isin name'].isin(ignore_list)][['master id','isin name']].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_61206">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61206_level0_col0" class="col_heading level0 col0" >master id</th>
#       <th id="T_61206_level0_col1" class="col_heading level0 col1" >isin name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61206_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_61206_row0_col0" class="data row0 col0" >140871</td>
#       <td id="T_61206_row0_col1" class="data row0 col1" >GB0000796242</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_61206_row1_col0" class="data row1 col0" >141792</td>
#       <td id="T_61206_row1_col1" class="data row1 col1" >IE00043JTBZ6</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_61206_row2_col0" class="data row2 col0" >140884</td>
#       <td id="T_61206_row2_col1" class="data row2 col1" >IE000G1ER031</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_61206_row3_col0" class="data row3 col0" >140885</td>
#       <td id="T_61206_row3_col1" class="data row3 col1" >IE000IQEE9W5</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row4" class="row_heading level0 row4" >19</th>
#       <td id="T_61206_row4_col0" class="data row4 col0" >140886</td>
#       <td id="T_61206_row4_col1" class="data row4 col1" >IE000J9WOV28</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row5" class="row_heading level0 row5" >20</th>
#       <td id="T_61206_row5_col0" class="data row5 col0" >141791</td>
#       <td id="T_61206_row5_col1" class="data row5 col1" >IE000RC8IBP7</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row6" class="row_heading level0 row6" >21</th>
#       <td id="T_61206_row6_col0" class="data row6 col0" >141810</td>
#       <td id="T_61206_row6_col1" class="data row6 col1" >IE000YLJKBQ9</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row7" class="row_heading level0 row7" >22</th>
#       <td id="T_61206_row7_col0" class="data row7 col0" >141793</td>
#       <td id="T_61206_row7_col1" class="data row7 col1" >IE000Z0DPSS4</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row8" class="row_heading level0 row8" >38</th>
#       <td id="T_61206_row8_col0" class="data row8 col0" >138573</td>
#       <td id="T_61206_row8_col1" class="data row8 col1" >IE00B7F9FM77</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row9" class="row_heading level0 row9" >57</th>
#       <td id="T_61206_row9_col0" class="data row9 col0" >138574</td>
#       <td id="T_61206_row9_col1" class="data row9 col1" >IE00B9NNHV84</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row10" class="row_heading level0 row10" >76</th>
#       <td id="T_61206_row10_col0" class="data row10 col0" >138093</td>
#       <td id="T_61206_row10_col1" class="data row10 col1" >IE00BGR6TZ09</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row11" class="row_heading level0 row11" >86</th>
#       <td id="T_61206_row11_col0" class="data row11 col0" >140905</td>
#       <td id="T_61206_row11_col1" class="data row11 col1" >IE00BKPHWW11</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row12" class="row_heading level0 row12" >87</th>
#       <td id="T_61206_row12_col0" class="data row12 col0" >140906</td>
#       <td id="T_61206_row12_col1" class="data row12 col1" >IE00BKPHWX28</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row13" class="row_heading level0 row13" >88</th>
#       <td id="T_61206_row13_col0" class="data row13 col0" >140907</td>
#       <td id="T_61206_row13_col1" class="data row13 col1" >IE00BLSP4015</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row14" class="row_heading level0 row14" >89</th>
#       <td id="T_61206_row14_col0" class="data row14 col0" >138004</td>
#       <td id="T_61206_row14_col1" class="data row14 col1" >IE00BLSP4122</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row15" class="row_heading level0 row15" >93</th>
#       <td id="T_61206_row15_col0" class="data row15 col0" >141794</td>
#       <td id="T_61206_row15_col1" class="data row15 col1" >IE00BMG7P694</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row16" class="row_heading level0 row16" >94</th>
#       <td id="T_61206_row16_col0" class="data row16 col0" >140794</td>
#       <td id="T_61206_row16_col1" class="data row16 col1" >IE00BMG7P819</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row17" class="row_heading level0 row17" >95</th>
#       <td id="T_61206_row17_col0" class="data row17 col0" >140795</td>
#       <td id="T_61206_row17_col1" class="data row17 col1" >IE00BMG7P926</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row18" class="row_heading level0 row18" >104</th>
#       <td id="T_61206_row18_col0" class="data row18 col0" >140914</td>
#       <td id="T_61206_row18_col1" class="data row18 col1" >IE00BN6Q8645</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row19" class="row_heading level0 row19" >115</th>
#       <td id="T_61206_row19_col0" class="data row19 col0" >140919</td>
#       <td id="T_61206_row19_col1" class="data row19 col1" >IE00BWDBJ409</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row20" class="row_heading level0 row20" >170</th>
#       <td id="T_61206_row20_col0" class="data row20 col0" >140950</td>
#       <td id="T_61206_row20_col1" class="data row20 col1" >LU0057025933</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row21" class="row_heading level0 row21" >187</th>
#       <td id="T_61206_row21_col0" class="data row21 col0" >140961</td>
#       <td id="T_61206_row21_col1" class="data row21 col1" >LU0081336892</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row22" class="row_heading level0 row22" >212</th>
#       <td id="T_61206_row22_col0" class="data row22 col0" >140970</td>
#       <td id="T_61206_row22_col1" class="data row22 col1" >LU0110060430</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row23" class="row_heading level0 row23" >234</th>
#       <td id="T_61206_row23_col0" class="data row23 col0" >138143</td>
#       <td id="T_61206_row23_col1" class="data row23 col1" >LU0156897901</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row24" class="row_heading level0 row24" >235</th>
#       <td id="T_61206_row24_col0" class="data row24 col0" >137980</td>
#       <td id="T_61206_row24_col1" class="data row24 col1" >LU0157308031</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row25" class="row_heading level0 row25" >298</th>
#       <td id="T_61206_row25_col0" class="data row25 col0" >141005</td>
#       <td id="T_61206_row25_col1" class="data row25 col1" >LU0232524495</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row26" class="row_heading level0 row26" >321</th>
#       <td id="T_61206_row26_col0" class="data row26 col0" >138146</td>
#       <td id="T_61206_row26_col1" class="data row26 col1" >LU0258954014</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row27" class="row_heading level0 row27" >322</th>
#       <td id="T_61206_row27_col0" class="data row27 col0" >138594</td>
#       <td id="T_61206_row27_col1" class="data row27 col1" >LU0258954444</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row28" class="row_heading level0 row28" >351</th>
#       <td id="T_61206_row28_col0" class="data row28 col0" >138596</td>
#       <td id="T_61206_row28_col1" class="data row28 col1" >LU0288029514</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row29" class="row_heading level0 row29" >352</th>
#       <td id="T_61206_row29_col0" class="data row29 col0" >138597</td>
#       <td id="T_61206_row29_col1" class="data row29 col1" >LU0288029860</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row30" class="row_heading level0 row30" >353</th>
#       <td id="T_61206_row30_col0" class="data row30 col0" >141034</td>
#       <td id="T_61206_row30_col1" class="data row30 col1" >LU0289739343</td>
#     </tr>
#     <tr>
#       <th id="T_61206_level0_row31" class="row_heading level0 row31" >354</th>
#       <td id="T_61206_row31_col0" class="data row31
